# %%
import matplotlib.pyplot as plt
# Seus dados
dados = [
   (0, 5.00, 0.00),
   (401, 3.34, 1.66),
   (803, 2.24, 2.76),
   (1205, 1.50, 3.50),
   (1607, 1.00, 4.00),
   (2010, 0.67, 4.33),
   (2412, 0.45, 4.55),
   (2813, 0.30, 4.70),
   (3216, 0.20, 4.80),
   (3618, 0.14, 4.86),
   (4021, 0.09, 4.91),
   (4423, 0.06, 4.94),
   (4825, 0.04, 4.96),
   (5227, 0.03, 4.97),
   (5629, 0.02, 4.98),
   (6032, 0.01, 4.99),
   (6433, 0.01, 4.99),
   (6836, 0.00, 5.00),
   (7238, 0.00, 5.00),
   (7641, 0.00, 5.00),
   (8043, 0.00, 5.00)
]
# Separando os dados
x = [item[0] for item in dados]
y1 = [item[1] for item in dados]
y2 = [item[2] for item in dados]
# Criando o gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y1, label='Tensão no Resistor')
plt.plot(x, y2, label='Tensão no Capacitor')
# Configurando rótulos e título
plt.xlabel('Tempo (milisegundos)')
plt.ylabel('Valores da Tensão (volts)')
plt.title('Comparação entre a tensão no capacitor e no resistor')
plt.legend()
plt.grid(True)
# Salvando o gráfico ANTES de exibir
plt.savefig('tensao_comparacao.png', dpi=300, bbox_inches='tight')
# Exibindo o gráfico
plt.show()
